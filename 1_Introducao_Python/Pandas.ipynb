# %% [markdown]
# ## Nesse material vamos ver exemplos de manipulação de uma tabela de dados utilizando o Pandas.
#
# Os arquivos utilizados foram extraídos do site: https://www.kaggle.com/competitions/titanic/data
#
# O Kaggle é uma subsidiária da Google LLC, sendo uma comunidade on-line de cientistas de dados e praticantes de aprendizado de máquina

# %% [markdown]
# ## Importar o Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Ler DataFrame de arquivo CSV

# %%
data = pd.read_csv('titanic/train.csv') # Comma Separated Values - Valores Separados Por Vírgula

# %% [markdown]
# ## Ler as primeiras linhas

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ## Ler as últimas linhas

# %%
data.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# ## Verificar as informações do dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Podemos ver um resumo estatístico desses dados (dados numéricos)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Também podemos verificar um resumo estatístico de campos categóricos

# %%
data.describe(include='O')
# Out:
#                     Name   Sex Ticket        Cabin Embarked
# count                891   891    891          204      889
# unique               891     2    681          147        3
# top     Ward, Miss. Anna  male   1601  C23 C25 C27        S
# freq                   1   577      7            4      644

# %% [markdown]
# ## Como assim categóricos? Vamos analisar o campo Sexo

# %%
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %% [markdown]
# ## E o campo Cabine

# %%
data['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# ## Após verificar os dados, podemos começar manipulá-los. Uma das primeiras operações, a fim de facilitar o uso das colunas, é renomeá-las.

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Para tanto, um novo dicionário é passado como argumento em rename. Veja de Name vai para Nome. De Sex é renomeado para Sexo.

# %%
data.rename({'Name': 'Nome', 'Sex': 'Sexo'}, axis=1, inplace=True)

# %% [markdown]
# ## Realizando somente a leitura das colunas, temos:

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Nome', 'Sexo', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## E se eu quiser renomear todas as colunas de uma só vez? Posso criar uma lista de nomes de colunas.

# %%
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 
                'IrmaosConjuge','PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']

# %%
data.head(2)
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
#
#    IrmaosConjuge  PaisFilhos    Bilhete   Tarifa Cabine Embarque
# 0              1           0  A/5 21171   7.2500    NaN        S
# 1              1           0   PC 17599  71.2833    C85        C

# %%
data.columns
# Out:
# Index(['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade',
#        'IrmaosConjuge', 'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine',
#        'Embarque'],
#       dtype='object')

# %% [markdown]
# ## Suponha que voce tenha um dataset muito grande, com várias colunas. No entanto, voce gostaria de visualizar apenas algumas delas.
#
# Voce passa uma lista de nomes em data[]. Veja que é data[[...]].head()

# %%
data[['Nome', 'Sexo', 'Classe', 'Tarifa', 'Idade', 'Sobreviveu']].head()
# Out:
#                                                 Nome    Sexo  Classe   Tarifa  \
# 0                            Braund, Mr. Owen Harris    male       3   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1  71.2833
# 2                             Heikkinen, Miss. Laina  female       3   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1  53.1000
# 4                           Allen, Mr. William Henry    male       3   8.0500
#
#    Idade  Sobreviveu
# 0   22.0           0
# 1   38.0           1
# 2   26.0           1
# 3   35.0           1
# 4   35.0           0

# %% [markdown]
# ## Selecionando apenas uma coluna para visualização

# %%
data['Idade'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Idade, dtype: float64

# %% [markdown]
# ## Podemos fazer algumas operações matemáticas com esses dados. Vamos relembrar:
#
#
# * Média:
# A média aritmética simples é a somatória de todos os elementos dividido pelo número de elmentos:
#
# $$\bar{X} = \frac{x_{1} + x_{2} + x_{3} +\cdots + x_{n}}{n}$$
#
# * Desvio padrão: Se $\bar{X}$ é a média aritmética de uma amostra de números x1, x2, … , xn, chama-se desvio absoluto médio o número:
#
# $$STD= \frac{\left | x_{1} - \bar{X} \right | + \left | x_{2} - \bar{X} \right | + \left | x_{3} - \bar{X} \right | + \cdots \left | x_{n} - \bar{X} \right |}{n}$$
#
# * Mediana:
# É o valor que divide o conjunto em dois subconjuntos, em que estes subconjuntos formados terão exatamente a mesma quantidade de elementos.
#
#
# * Moda: é o valor mais frequente em determinado conjunto

# %%
data['Idade'].std() #desvio padrão da idade
# Out:
# 14.526497332334044

# %%
data['Idade'].mean() #media das idades
# Out:
# 29.69911764705882

# %%
data['Idade'].sum() #soma das idades
# Out:
# 21205.17

# %%
data['Idade'].count() #número de linhas que possuem dados de Idade
# Out:
# 714

# %%
data['Idade'].median() #mediana da Idade
# Out:
# 28.0

# %%
data['Idade'].mode() #Moda da idade
# Out:
# 0    24.0
# dtype: float64

# %%
data['Idade'].max() #o valor máximo de idade
# Out:
# 80.0

# %%
data['Idade'].min() #o valor mínimo de idade. Voce pode multiplicar por 12 para ver em anos.
# Out:
# 0.42

# %%
data['Idade'].idxmin() #Qual o índice da pessoa mais nova.
# Out:
# 803

# %%
data['Idade'].idxmax() #Qual o índice da pessoa mais velha
# Out:
# 630

# %% [markdown]
# ## Podemos também verificar a média, soma, mediana de todas as colunas do dataset

# %%
data.mean()
# Out:
# IdPassageiro     446.000000
# Sobreviveu         0.383838
# Classe             2.308642
# Idade             29.699118
# IrmaosConjuge      0.523008
# PaisFilhos         0.381594
# Tarifa            32.204208
# dtype: float64

# %%
data.sum()
# Out:
# IdPassageiro                                                397386
# Sobreviveu                                                     342
# Classe                                                        2057
# Nome             Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sexo             malefemalefemalefemalemalemalemalemalefemalefe...
# Idade                                                     21205.17
# IrmaosConjuge                                                  466
# PaisFilhos                                                     340
# Bilhete          A/5 21171PC 17599STON/O2. 31012821138033734503...
# Tarifa                                                  28693.9493
# dtype: object

# %%
data.median()
# Out:
# IdPassageiro     446.0000
# Sobreviveu         0.0000
# Classe             3.0000
# Idade             28.0000
# IrmaosConjuge      0.0000
# PaisFilhos         0.0000
# Tarifa            14.4542
# dtype: float64

# %%
data.min()
# Out:
# IdPassageiro                       1
# Sobreviveu                         0
# Classe                             1
# Nome             Abbing, Mr. Anthony
# Sexo                          female
# Idade                           0.42
# IrmaosConjuge                      0
# PaisFilhos                         0
# Bilhete                       110152
# Tarifa                           0.0
# dtype: object

# %% [markdown]
# ## Selecionando pelo Index
#
# No pandas temos duas maneiras muito interessantes de resgatar os dados que queremos, são elas:
#
# * loc;
# * iloc;
#
# ## Quando usar loc ou iloc?
# Basicamente os dois métodos servem para resgatar dados, mas possuem características distintas na hora que vamos utilizá-los.
#
# Vamos entender agora quais são as particularidades deles e os casos de uso para cada um.
#
# ## loc:
# Este método é primariamente baseado nas labels da colunas, porém podemos utilizar com um array booleano também.
#
# Uma informação importante sobre loc é: quando nenhum item é encontrado ele retorna um KeyError.
#
# Funcionamento do método:
#
# O método funciona desta maneira:
#
# `df.loc[linhas, colunas]`
#
#
#
# Primeiro argumento são as linhas e o segundo as colunas a serem buscadas.

# %%
#podemos chamar uma linha pelo seu índice
data.loc[5]
# Out:
# IdPassageiro                    6
# Sobreviveu                      0
# Classe                          3
# Nome             Moran, Mr. James
# Sexo                         male
# Idade                         NaN
# IrmaosConjuge                   0
# PaisFilhos                      0
# Bilhete                    330877
# Tarifa                     8.4583
# Cabine                        NaN
# Embarque                        Q
# Name: 5, dtype: object

# %%
#ou com um array de índices
data.loc[[0,1,2]]
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
#
#    IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0              1           0         A/5 21171   7.2500    NaN        S
# 1              1           0          PC 17599  71.2833    C85        C
# 2              0           0  STON/O2. 3101282   7.9250    NaN        S

# %%
# uma fatia, do quarto ao sétimo elemento (note que diferente do python puro, neste método a chave inicial e final estarão presente no resultado)
data.loc[4:8]
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 4             5           0       3
# 5             6           0       3
# 6             7           0       1
# 7             8           0       3
# 8             9           1       3
#
#                                                 Nome    Sexo  Idade  \
# 4                           Allen, Mr. William Henry    male   35.0
# 5                                   Moran, Mr. James    male    NaN
# 6                            McCarthy, Mr. Timothy J    male   54.0
# 7                     Palsson, Master. Gosta Leonard    male    2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27.0
#
#    IrmaosConjuge  PaisFilhos Bilhete   Tarifa Cabine Embarque
# 4              0           0  373450   8.0500    NaN        S
# 5              0           0  330877   8.4583    NaN        Q
# 6              0           0   17463  51.8625    E46        S
# 7              3           1  349909  21.0750    NaN        S
# 8              0           2  347742  11.1333    NaN        S

# %% [markdown]
# ## iloc
# Há outros casos de uso de loc, porém aqui conseguimos ver os principais, ou melhor dizendo, as maneiras que podem nos levar aos demais usos,
#
# Vamos para o iloc!
#
# iloc:
# O indexador iloc é um tanto mais simples, ele seleciona por números inteiros das linhas, arrays ou por slice.
#
# Como o loc, ele funciona desta maneira:
#
# `df.iloc[<linhas>, <colunas>]`
#
# Os dois argumentos são: linhas e colunas,
#
# Podemos concluir que o iloc seleciona linhas e colunas por números, esta é uma boa definição para o recurso.

# %%
# Linhas:
data.iloc[0]  # Selecionado a primeira linha do dataset
# Out:
# IdPassageiro                           1
# Sobreviveu                             0
# Classe                                 3
# Nome             Braund, Mr. Owen Harris
# Sexo                                male
# Idade                               22.0
# IrmaosConjuge                          1
# PaisFilhos                             0
# Bilhete                        A/5 21171
# Tarifa                              7.25
# Cabine                               NaN
# Embarque                               S
# Name: 0, dtype: object

# %%
data.iloc[-1] # Selecionando a última linha
# Out:
# IdPassageiro                     891
# Sobreviveu                         0
# Classe                             3
# Nome             Dooley, Mr. Patrick
# Sexo                            male
# Idade                           32.0
# IrmaosConjuge                      0
# PaisFilhos                         0
# Bilhete                       370376
# Tarifa                          7.75
# Cabine                           NaN
# Embarque                           Q
# Name: 890, dtype: object

# %%
data.iloc[630] #selecinando o passageiro do índice 630
# Out:
# IdPassageiro                                      631
# Sobreviveu                                          1
# Classe                                              1
# Nome             Barkworth, Mr. Algernon Henry Wilson
# Sexo                                             male
# Idade                                            80.0
# IrmaosConjuge                                       0
# PaisFilhos                                          0
# Bilhete                                         27042
# Tarifa                                           30.0
# Cabine                                            A23
# Embarque                                            S
# Name: 630, dtype: object

# %%
data.iloc[803] ##selecinando o passageiro do índice 803
# Out:
# IdPassageiro                                 804
# Sobreviveu                                     1
# Classe                                         3
# Nome             Thomas, Master. Assad Alexander
# Sexo                                        male
# Idade                                       0.42
# IrmaosConjuge                                  0
# PaisFilhos                                     1
# Bilhete                                     2625
# Tarifa                                    8.5167
# Cabine                                       NaN
# Embarque                                       C
# Name: 803, dtype: object

# %%
data.iloc[[803]] #transformando a busca para exibir como dataframe
# Out:
#      IdPassageiro  Sobreviveu  Classe                             Nome  Sexo  \
# 803           804           1       3  Thomas, Master. Assad Alexander  male
#
#      Idade  IrmaosConjuge  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 803   0.42              0           1    2625  8.5167    NaN        C

# %%
data.iloc[[630]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Sexo  Idade  IrmaosConjuge  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 630  male   80.0              0           0   27042    30.0    A23        S

# %%
data.iloc[[630,70,803,80]] #realizando uma busca de 4 passageiros pelos seus índices
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
# 70             71           0       2            Jenkin, Mr. Stephen Curnow
# 803           804           1       3       Thomas, Master. Assad Alexander
# 80             81           0       3                  Waelens, Mr. Achille
#
#      Sexo  Idade  IrmaosConjuge  PaisFilhos     Bilhete   Tarifa Cabine  \
# 630  male  80.00              0           0       27042  30.0000    A23
# 70   male  32.00              0           0  C.A. 33111  10.5000    NaN
# 803  male   0.42              0           1        2625   8.5167    NaN
# 80   male  22.00              0           0      345767   9.0000    NaN
#
#     Embarque
# 630        S
# 70         S
# 803        C
# 80         S

# %%
data.iloc[2:5] #selecionando os índices 2 a 4
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                            Nome    Sexo  Idade  IrmaosConjuge  \
# 2                        Heikkinen, Miss. Laina  female   26.0              0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0              1
# 4                      Allen, Mr. William Henry    male   35.0              0
#
#    PaisFilhos           Bilhete  Tarifa Cabine Embarque
# 2           0  STON/O2. 3101282   7.925    NaN        S
# 3           0            113803  53.100   C123        S
# 4           0            373450   8.050    NaN        S

# %%
data['Nome'].iloc[2] #selecionando o nome do índice 2
# Out:
# 'Heikkinen, Miss. Laina'

# %%
data['Idade'].iloc[630] #selecionando a idade do passageiro de indice 630
# Out:
# 80.0

# %%
data['Idade'].iloc[803] ##selecionando a idade do passageiro de indice 803
# Out:
# 0.42

# %% [markdown]
# ## Operações avançadas com loc
#
# podemos combinar operadores lógicos para chegar no resultado que queremos.

# %% [markdown]
# ### Selecionar os passageiros e as colunas idade, sexo, tarifa, classe e sobreviveu quando a idade for maior que 70

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']].loc[data['Idade']>70]
# Out:
#      Idade  Sexo   Tarifa  Classe  Sobreviveu
# 96    71.0  male  34.6542       1           0
# 116   70.5  male   7.7500       3           0
# 493   71.0  male  49.5042       1           0
# 630   80.0  male  30.0000       1           1
# 851   74.0  male   7.7750       3           0

# %% [markdown]
# ### Selecionar os passageiros, apresentando as colunas Idade, sexo, tarifa, classe, sobreviveu, quando sexo for igual a female (feminino).

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']].loc[data['Sexo']=='female'].head()
# Out:
#    Idade    Sexo   Tarifa  Classe  Sobreviveu
# 1   38.0  female  71.2833       1           1
# 2   26.0  female   7.9250       3           1
# 3   35.0  female  53.1000       1           1
# 8   27.0  female  11.1333       3           1
# 9   14.0  female  30.0708       2           1

# %% [markdown]
# Se tirar o .head() do comando ele mostra todos os selecionados.

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']].loc[data['Sexo']=='female']
# Out:
#      Idade    Sexo   Tarifa  Classe  Sobreviveu
# 1     38.0  female  71.2833       1           1
# 2     26.0  female   7.9250       3           1
# 3     35.0  female  53.1000       1           1
# 8     27.0  female  11.1333       3           1
# 9     14.0  female  30.0708       2           1
# ..     ...     ...      ...     ...         ...
# 880   25.0  female  26.0000       2           1
# 882   22.0  female  10.5167       3           0
# 885   39.0  female  29.1250       3           0
# 887   19.0  female  30.0000       1           1
# 888    NaN  female  23.4500       3           0
#
# [314 rows x 5 columns]

# %% [markdown]
# ## Selecionando com múltiplas condições
#
# Selecione os passageiros retornando Idade, sexo, tarifa, classe, sobreviveu, quando a idade for maior que 3 e menor que 10, e que não sobreviveram.

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>=3) & (data['Idade']<=10) & ~(data['Sobreviveu']==1)]
# Out:
#      Idade    Sexo   Tarifa  Classe  Sobreviveu
# 24     8.0  female  21.0750       3           0
# 50     7.0    male  39.6875       3           0
# 63     4.0    male  27.9000       3           0
# 147    9.0  female  34.3750       3           0
# 171    4.0    male  29.1250       3           0
# 182    9.0    male  31.3875       3           0
# 278    7.0    male  29.1250       3           0
# 374    3.0  female  21.0750       3           0
# 419   10.0  female  24.1500       3           0
# 480    9.0    male  46.9000       3           0
# 541    9.0  female  31.2750       3           0
# 634    9.0  female  27.9000       3           0
# 787    8.0    male  29.1250       3           0
# 813    6.0  female  31.2750       3           0
# 819   10.0    male  27.9000       3           0
# 850    4.0    male  31.2750       3           0
# 852    9.0  female  15.2458       3           0

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>=3) & (data['Idade']<=10) & ~(data['Sobreviveu']==1)].count()
# Out:
# Idade         17
# Sexo          17
# Tarifa        17
# Classe        17
# Sobreviveu    17
# dtype: int64

# %% [markdown]
# ### E que sobreviveram

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>=3) & (data['Idade']<=10) & (data['Sobreviveu']==1)]
# Out:
#      Idade    Sexo   Tarifa  Classe  Sobreviveu
# 10     4.0  female  16.7000       3           1
# 43     3.0  female  41.5792       2           1
# 58     5.0  female  27.7500       2           1
# 165    9.0    male  20.5250       3           1
# 184    4.0  female  22.0250       3           1
# 193    3.0    male  26.0000       2           1
# 233    5.0  female  31.3875       3           1
# 237    8.0  female  26.2500       2           1
# 261    3.0    male  31.3875       3           1
# 348    3.0    male  15.9000       3           1
# 407    3.0    male  18.7500       2           1
# 445    4.0    male  81.8583       1           1
# 448    5.0  female  19.2583       3           1
# 489    9.0    male  15.9000       3           1
# 535    7.0  female  26.2500       2           1
# 549    8.0    male  36.7500       2           1
# 618    4.0  female  39.0000       2           1
# 691    4.0  female  13.4167       3           1
# 720    6.0  female  33.0000       2           1
# 750    4.0  female  23.0000       2           1
# 751    6.0    male  12.4750       3           1
# 777    5.0  female  12.4750       3           1
# 869    4.0    male  11.1333       3           1

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>=3) & (data['Idade']<=10) & (data['Sobreviveu']==1)].count()
# Out:
# Idade         23
# Sexo          23
# Tarifa        23
# Classe        23
# Sobreviveu    23
# dtype: int64

# %% [markdown]
# ## Vejamos mais alguns exemplos
#
# Selecionar Idade, sexo, classe, sobreviveu, quando idade for maior que 14, sobreviveram = 1, do sexo masculino e a classe 3.

# %%
data[['Idade', 'Sexo','Classe', 'Sobreviveu']]\
.loc[(data['Idade']>14) \
     & (data['Sobreviveu']==1) \
     & (data['Sexo']=='male')\
    & (data['Classe']==3)]
# Out:
#      Idade  Sexo  Classe  Sobreviveu
# 74    32.0  male       3           1
# 81    29.0  male       3           1
# 127   24.0  male       3           1
# 146   27.0  male       3           1
# 204   18.0  male       3           1
# 207   26.0  male       3           1
# 220   16.0  male       3           1
# 267   25.0  male       3           1
# 271   25.0  male       3           1
# 283   19.0  male       3           1
# 286   30.0  male       3           1
# 338   45.0  male       3           1
# 391   21.0  male       3           1
# 400   39.0  male       3           1
# 414   44.0  male       3           1
# 429   32.0  male       3           1
# 455   29.0  male       3           1
# 509   26.0  male       3           1
# 510   29.0  male       3           1
# 553   22.0  male       3           1
# 569   32.0  male       3           1
# 579   32.0  male       3           1
# 622   20.0  male       3           1
# 664   20.0  male       3           1
# 744   31.0  male       3           1
# 762   20.0  male       3           1
# 804   27.0  male       3           1
# 821   27.0  male       3           1
# 838   32.0  male       3           1

# %%
data[['Idade', 'Sexo','Classe', 'Sobreviveu']]\
.loc[(data['Idade']>14) \
     & (data['Sobreviveu']==1) \
     & (data['Sexo']=='male')\
    & (data['Classe']==3)].count()
# Out:
# Idade         29
# Sexo          29
# Classe        29
# Sobreviveu    29
# dtype: int64

# %% [markdown]
# ## E que não sobreviveram

# %%
data[['Idade', 'Sexo','Classe', 'Sobreviveu']]\
.loc[(data['Idade']>14) \
     & ~(data['Sobreviveu']==1) \
     & (data['Sexo']=='male')\
    & (data['Classe']==3)]
# Out:
#      Idade  Sexo  Classe  Sobreviveu
# 0     22.0  male       3           0
# 4     35.0  male       3           0
# 12    20.0  male       3           0
# 13    39.0  male       3           0
# 37    21.0  male       3           0
# ..     ...   ...     ...         ...
# 876   20.0  male       3           0
# 877   19.0  male       3           0
# 881   33.0  male       3           0
# 884   25.0  male       3           0
# 890   32.0  male       3           0
#
# [197 rows x 4 columns]

# %% [markdown]
# ## Map e replace
#
# Podemos usar essas funções para substituir valores dentro do dataframe. Principalmente para alguma tradução, modificação de números. Contudo isso não atualiza definitivamente no dataframe original. Veja os exemplos abaixo.

# %%
data['Sexo'].map({'male': 'homem', 'female': 'mulher'}).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0              1           0         A/5 21171   7.2500    NaN        S
# 1              1           0          PC 17599  71.2833    C85        C
# 2              0           0  STON/O2. 3101282   7.9250    NaN        S
# 3              1           0            113803  53.1000   C123        S
# 4              0           0            373450   8.0500    NaN        S

# %%
data['Sexo'].replace(['homem','mulher'], ['male','female'], inplace=True)

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0              1           0         A/5 21171   7.2500    NaN        S
# 1              1           0          PC 17599  71.2833    C85        C
# 2              0           0  STON/O2. 3101282   7.9250    NaN        S
# 3              1           0            113803  53.1000   C123        S
# 4              0           0            373450   8.0500    NaN        S

# %% [markdown]
# ### Agora se for atribuido que, para data['Sexo'] vai receber um novo valor de mapeamento...

# %%
data['Sexo'] = data['Sexo'].map({'male': 'homem', 'female': 'mulher'})

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0              1           0         A/5 21171   7.2500    NaN        S
# 1              1           0          PC 17599  71.2833    C85        C
# 2              0           0  STON/O2. 3101282   7.9250    NaN        S
# 3              1           0            113803  53.1000   C123        S
# 4              0           0            373450   8.0500    NaN        S

# %% [markdown]
# ## Groupby - Agrupar por
#
# Uma operação groupby envolve alguma combinação de divisão do objeto, aplicação de uma função e combinação dos resultados. Isso pode ser usado para agrupar grandes quantidades de dados e operações de computação nesses grupos.

# %%
data.groupby('Sexo').mean()
# Out:
#         IdPassageiro  Sobreviveu    Classe      Idade  IrmaosConjuge  \
# Sexo
# homem     454.147314    0.188908  2.389948  30.726645       0.429809
# mulher    431.028662    0.742038  2.159236  27.915709       0.694268
#
#         PaisFilhos     Tarifa
# Sexo
# homem     0.235702  25.523893
# mulher    0.649682  44.479818

# %%
data.groupby('Sobreviveu').mean()
# Out:
#             IdPassageiro    Classe      Idade  IrmaosConjuge  PaisFilhos  \
# Sobreviveu
# 0             447.016393  2.531876  30.626179       0.553734    0.329690
# 1             444.368421  1.950292  28.343690       0.473684    0.464912
#
#                Tarifa
# Sobreviveu
# 0           22.117887
# 1           48.395408

# %%
data.groupby('Classe').mean()
# Out:
#         IdPassageiro  Sobreviveu      Idade  IrmaosConjuge  PaisFilhos  \
# Classe
# 1         461.597222    0.629630  38.233441       0.416667    0.356481
# 2         445.956522    0.472826  29.877630       0.402174    0.380435
# 3         439.154786    0.242363  25.140620       0.615071    0.393075
#
#            Tarifa
# Classe
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
data.groupby(['Sexo','Classe']).mean()
# Out:
#                IdPassageiro  Sobreviveu      Idade  IrmaosConjuge  PaisFilhos  \
# Sexo   Classe
# homem  1         455.729508    0.368852  41.281386       0.311475    0.278689
#        2         447.962963    0.157407  30.740707       0.342593    0.222222
#        3         455.515850    0.135447  26.507589       0.498559    0.224784
# mulher 1         469.212766    0.968085  34.611765       0.553191    0.457447
#        2         443.105263    0.921053  28.722973       0.486842    0.605263
#        3         399.729167    0.500000  21.750000       0.895833    0.798611
#
#                    Tarifa
# Sexo   Classe
# homem  1        67.226127
#        2        19.741782
#        3        12.661633
# mulher 1       106.125798
#        2        21.970121
#        3        16.118810

# %% [markdown]
# ## Crosstab
#
# calcula uma tabela de frequência dos fatores

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], margins=True).style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
# #T_f5bbc_row0_col0,#T_f5bbc_row1_col1,#T_f5bbc_row1_col2,#T_f5bbc_row1_col3{
#             background-color:  #fff7ec;
#             color:  #000000;
#         }#T_f5bbc_row0_col1{
#             background-color:  #feebcf;
#             color:  #000000;
#         }#T_f5bbc_row0_col2{
#             background-color:  #e44d35;
#             color:  #000000;
#         }#T_f5bbc_row0_col3{
#             background-color:  #fdba83;
#             color:  #000000;
#         }#T_f5bbc_row1_col0{
#             background-color:  #fdad77;
#             color:  #000000;
#         }#T_f5bbc_row2_col0,#T_f5bbc_row2_col1,#T_f5bbc_row2_col2,#T_f5bbc_row2_col3{
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }</style><table id="T_f5bbc_" ><thead>    <tr>        <th class="index_name level0" >Classe</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sobreviveu</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5bbc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f5bbc_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_f5bbc_row0_col1" class="data row0 col1" >97</td>
#                         <td id="T_f5bbc_row0_col2" class="data row0 col2" >372</td>
#                         <td id="T_f5bbc_row0_col3" class="data row0 col3" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_f5bbc_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f5bbc_row1_col0" class="data row1 col0" >136</td>
#                         <td id="T_f5bbc_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_f5bbc_row1_col2" class="data row1 col2" >119</td>
#                         <td id="T_f5bbc_row1_col3" class="data row1 col3" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_f5bbc_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_f5bbc_row2_col0" class="data row2 col0" >216</td>
#                         <td id="T_f5bbc_row2_col1" class="data row2 col1" >184</td>
#                         <td id="T_f5bbc_row2_col2" class="data row2 col2" >491</td>
#                         <td id="T_f5bbc_row2_col3" class="data row2 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(data['Sobreviveu'], data['Sexo'], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_2d5ab_row0_col0{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_2d5ab_row0_col1,#T_2d5ab_row1_col0,#T_2d5ab_row1_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_2d5ab_row0_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_2d5ab_row1_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_2d5ab_row2_col0,#T_2d5ab_row2_col1,#T_2d5ab_row2_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_2d5ab_" ><thead>    <tr>        <th class="index_name level0" >Sexo</th>        <th class="col_heading level0 col0" >homem</th>        <th class="col_heading level0 col1" >mulher</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sobreviveu</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2d5ab_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2d5ab_row0_col0" class="data row0 col0" >468</td>
#                         <td id="T_2d5ab_row0_col1" class="data row0 col1" >81</td>
#                         <td id="T_2d5ab_row0_col2" class="data row0 col2" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_2d5ab_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2d5ab_row1_col0" class="data row1 col0" >109</td>
#                         <td id="T_2d5ab_row1_col1" class="data row1 col1" >233</td>
#                         <td id="T_2d5ab_row1_col2" class="data row1 col2" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_2d5ab_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_2d5ab_row2_col0" class="data row2 col0" >577</td>
#                         <td id="T_2d5ab_row2_col1" class="data row2 col1" >314</td>
#                         <td id="T_2d5ab_row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Ordenando dados

# %%
data[['Idade','Sexo','Classe','Sobreviveu']].sort_values('Idade', ascending=True).head() #do menor para maior
# Out:
#      Idade    Sexo  Classe  Sobreviveu
# 803   0.42   homem       3           1
# 755   0.67   homem       2           1
# 644   0.75  mulher       3           1
# 469   0.75  mulher       3           1
# 78    0.83   homem       2           1

# %%
data[['Idade','Sexo','Classe','Sobreviveu']].sort_index(ascending=False).head() #do maior para menor
# Out:
#      Idade    Sexo  Classe  Sobreviveu
# 890   32.0   homem       3           0
# 889   26.0   homem       1           1
# 888    NaN  mulher       3           0
# 887   19.0  mulher       1           1
# 886   27.0   homem       2           0

# %% [markdown]
# ## Apply e Lambda

# %%
data['Idade'].apply(lambda x: x**2) #selecione idade e aplique a multiplicação da idade por 2
# Out:
# 0       484.0
# 1      1444.0
# 2       676.0
# 3      1225.0
# 4      1225.0
#         ...
# 886     729.0
# 887     361.0
# 888       NaN
# 889     676.0
# 890    1024.0
# Name: Idade, Length: 891, dtype: float64

# %%
data['Bilhete'] = data['Bilhete'].apply(lambda x: x[:-1])

# %%
data['Bilhete']
# Out:
# 0             A/5 2117
# 1              PC 1759
# 2      STON/O2. 310128
# 3                11380
# 4                37345
#             ...
# 886              21153
# 887              11205
# 888          W./C. 660
# 889              11136
# 890              37037
# Name: Bilhete, Length: 891, dtype: object

# %% [markdown]
# ## Variáveis Dummy
#
# Em estatística ou econometria, particularmente na análise de regressão, uma variável Dummy é aquela que toma o valor de "zero" ou "um" indicando a ausência ou presença de qualidades ou atributos.
#
# Essas variáveis são usadas como dispositivos para classificar dados em categorias mutuamente exclusivas.

# %%
data = pd.get_dummies(data,columns=['Sexo'],drop_first=True)

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome  Idade  IrmaosConjuge  \
# 0                            Braund, Mr. Owen Harris   22.0              1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0              1
# 2                             Heikkinen, Miss. Laina   26.0              0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0              1
# 4                           Allen, Mr. William Henry   35.0              0
#
#    PaisFilhos          Bilhete   Tarifa Embarque  Sexo_mulher
# 0           0         A/5 2117   7.2500        S            0
# 1           0          PC 1759  71.2833        C            1
# 2           0  STON/O2. 310128   7.9250        S            1
# 3           0            11380  53.1000        S            1
# 4           0            37345   8.0500        S            0

# %%
data[['Idade','Sexo_mulher','Classe','Sobreviveu']].head()
# Out:
#    Idade  Sexo_mulher  Classe  Sobreviveu
# 0   22.0            0       3           0
# 1   38.0            1       1           1
# 2   26.0            1       3           1
# 3   35.0            1       1           1
# 4   35.0            0       3           0

# %% [markdown]
# # Exercício
#
# Considere o arquivo CompanhiaMB.csv disponível no Moodle e realize as seguintes operações:
# * faça a leitura do arquivo via pandas
# * Verifique as informações dos dados
# * Apresente um resumo estatístico
# * Acesse os campos e defina quais são categóricos
# * Renomeie o nome das colunas para que todos tenham a primeira letra maiúscula
# * Para as variáveis nfilhos e idade_anos, apresente a média, moda, desvio padrão, mínimo e máximo
# * Encontre o índice do funcionário que possui a maior idade. Faça a localização (loc) e mostre todos os dados dele.
# * Faça um loc para apresentar se existem funcionários com idade maior de 40 anos.
